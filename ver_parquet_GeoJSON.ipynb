# %%
import geopandas as gpd
import pandas as pd

# %%
# Leer el archivo Parquet
df_comunas = pd.read_parquet('C:/Users/user/Documents/MAESTRIA/Analítica y Big Data/G2-Big-Data/base.data/medellin_neighborhoods.parquet')

# Mostrar las primeras filas del DataFrame
print(df_comunas.head())
# Out:
#    OBJECTID CODIGO      NOMBRE IDENTIFICACION LIMITEMUNICIPIOID  \
# 0       321     01     POPULAR       COMUNA 1               001
# 1       322     02  SANTA CRUZ       COMUNA 2               001
# 2       323     03    MANRIQUE       COMUNA 3               001
# 3       324     04    ARANJUEZ       COMUNA 4               001
# 4       325     05    CASTILLA       COMUNA 5               001
#
#    SUBTIPO_COMUNACORREGIMIENTO LINK_DOCUMENTO     SHAPEAREA      SHAPELEN  \
# 0                            1           None  3.098290e+06   9604.987826
# 1                            1           None  2.195875e+06   8597.714449
# 2                            1           None  5.096746e+06  12078.237108
# 3                            1           None  4.883731e+06   9643.089265
# 4                            1           None  6.064367e+06  16098.614898
#
#                                             geometry
# 0  b'\x01\x03\x00\x00\x00\x01\x00\x00\x00\x05\x15...
# ...

# %%
# Imprimir al menos tres valores completos de la variable 'geometry'
geometries2 = df_comunas['geometry'].head(3)
for i, geometry in enumerate(geometries2):
    print(f"Geometry {i+1}: {geometry}")
# Out:
# Geometry 1: b'\x01\x03\x00\x00\x00\x01\x00\x00\x00\x05\x15\x00\x00\xfe \x8d\xe2\x12\xe3R\xc0O\x08\xe4\x06\xa97\x19@\xf2\x17\xd9h\x14\xe3R\xc0\xb1{P\x96\xa67\x19@\xdb\xc4\xdb\x13\x17\xe3R\xc0=s\xb8\x96\xa67\x19@\x99\x99\x9a8\x18\xe3R\xc0Pb\x9doy7\x19@ \x9eX]\x19\xe3R\xc0\xb2i\x13\xb5Y7\x19@\xd5\x8ck\xab\x19\xe3R\xc0]\xa3\x97\xa3=7\x19@\xd7sS\x0f\x19\xe3R\xc0\xafx\x8b?\x1a7\x19@e\xdd\x13\xb0\x17\xe3R\xc0V(\x9f\x9e\x007\x19@^\xe1v\x94\x17\xe3R\xc0n\xc9xa\xfc6\x19@\xa2\x8bo\xd9\x16\xe3R\xc0\x05\xc5Q\xab\xdf6\x19@\xf8\xb6\xb7\xe7\x16\xe3R\xc0c\x9b\x9c\n\xcc6\x19@\xa7R\xf8\xec\x16\xe3R\xc0\xcaOA\xd2\xc46\x19@\xb4r\xf57\x18\xe3R\xc0\xeb0\xfaB\xa26\x19@\x07\xdc\xc1\x04\x19\xe3R\xc0\xcab7Y\x8a6\x19@\xbe\xf7\nd\x19\xe3R\xc03X\xe38\x7f6\x19@\xef\x84\xfcr\x19\xe3R\xc0\x10y/z}6\x19@\x1e\x90\xf0\xe1\x19\xe3R\xc0\x81\xb8\xa2\xe9o6\x19@\x02\x8f\xb40\x1a\xe3R\xc0\x05\x86\xabHf6\x19@wv\x8a{\x1a\xe3R\xc0|J\r\xf1\\6\x19@\xdc\x02[e\x1b\xe3R\xc0\xcf3\xbd\xc0?6\x19@\xbc2\x81\x8c\x1b\xe3R\xc0\xbc\xe9\x17\x0
# ...

# %%
# Leer el archivo geoJSON
gdf_postal = gpd.read_file('C:/Users/user/Documents/MAESTRIA/Analítica y Big Data/G2-Big-Data/datos.adicionales/codigo_postal.geojson')
# Convertir el GeoDataFrame a DataFrame de pandas
df_postal = pd.DataFrame(gdf_postal)

# Mostrar las primeras filas del DataFrame
print(df_postal.head())

# Imprimir al menos tres valores completos de la variable 'geometry'
geometries3 = gdf_postal['geometry'].head(3)
for i, geometry in enumerate(geometries3):
    print(f"Geometry {i+1}: {geometry}")
# Out:
#    OBJECTID codigo_postal zonapostalid  fecha_sincronizacion  Shape_Length  \
# 0         1        050011         0500         1713579301000   9879.257065
# 1         2        050012         0500         1713579301000   8080.055371
# 2         3        050013         0500         1713579301000   9531.815949
# 3         4        050014         0500         1713579301000  10511.544326
# 4         5        050015         0500         1713579301000   7131.933863
#
#      Shape_Area                                           geometry
# 0  2.871793e+06  POLYGON ((4719561.445 2252057.777, 4719559.383...
# 1  2.718733e+06  POLYGON ((4717246.655 2250553.552, 4717246.249...
# 2  3.702623e+06  POLYGON ((4718873.839 2250111.383, 4718870.283...
# 3  2.446316e+06  POLYGON ((4718980.712 2246702.658, 4718990.736...
# 4  2.202393e+06  POLYGON ((4715840.689 2249180.237, 4715839.169...
# ...
